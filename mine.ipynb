# %%
marks=int(input("Enter your marks"))
passingmarks=40
if marks >= passingmarks:
    print("Congrtulations! You hve passd the exam.")
else:
    print("Sorry! You have failed the exam. Better luck next time.")
# Out:
# Congrtulations! You hve passd the exam.
