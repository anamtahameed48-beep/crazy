# %%
day-no = string(input("Enter the day number (1-7): "))
if day-no == "1":
    print("Monday")
elif dAY-no == "2":
    Print("Tuesdy")
elif day-no == "3":
    print("Wednesday")
elif day-no == "4":
    print("Thursday")
elif day-no == "5":
    print("Friday")
elif day-no == "6":
    print("Saturday")
else:
    print("Sunday")
